# %%
str1='a,b,c,d,b,a'
'abcdcba'=='abcdcba'
# Out:
# True

# %%
str2='b,o,r,d,a,r'
'bordar'=='bordar'
# Out:
# True

# %%
str3='1,2,3,4,5'
'54321'=='54321'
# Out:
# True

# %%
str4='n,u,m,b,e,r'
'rembun'=='rembun'
