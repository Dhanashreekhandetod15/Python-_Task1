# %% [markdown]
# ### hyperlinks
# [Drive][https://drive.google.com/drive/folders/1yEh0t9fbQCvMW7Du1Rwi0-csAWlcefn_]

# %% [markdown]
# ### Image
# ![Screenshot 2025-10-29 171014.png](<attachment:Screenshot 2025-10-29 171014.png>)

# %% [markdown]
# ### Blockquotes
# > "Success is not final", "failure is not fatal"

# %% [markdown]
# #### changes text color
# <span style ="color: red">Warning!</span>

# %% [markdown]
# #### Resizing image
# <img src="C:\Users\ASUS\OneDrive\Pictures\image1.png" width="200">

# %% [markdown]
# #### Details and Summary
# <Details>"Jupyter Notebooks use Markdown, a lightweight markup language, to convert plain text into formatted HTML"<Details> and
# <summary>"This allows you to create rich, readable documents that combine code, equations, and explanatory text."<summary>
